# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import dirichlet

# %%
alpha = np.array([2, 5, 3])

sample = np.random.dirichlet(alpha, size=5000)

# %%
plt.figure(figsize=(12, 8))
plt.scatter(sample[:, 0], sample[:, 1], alpha=0.5, s=2)
plt.title('Random Samples from Dirichlet Distribution')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
sample
# Out:
# array([[0.20071063, 0.35155667, 0.4477327 ],
#        [0.32580126, 0.49683287, 0.17736587],
#        [0.24151348, 0.5659719 , 0.19251462],
#        ...,
#        [0.16897636, 0.58905364, 0.24197001],
#        [0.31981968, 0.42191419, 0.25826613],
#        [0.15692361, 0.73943036, 0.10364603]])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import timedelta
from scipy import optimize, interpolate, integrate, special
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from scipy.optimize import basinhopping
import warnings

# %%
df = pd.read_csv("../data/Divvy_Bicycle_Stations_-_Historical.csv")
df.head()
# Out:
#     ID               Timestamp              Station Name  Address  \
# 0  325  04/01/2020 12:06:07 AM   Clark St & Winnemac Ave      NaN
# 1  454  04/01/2020 12:06:07 AM  Broadway & Granville Ave      NaN
# 2   99  04/01/2020 12:06:07 AM   Lake Shore Dr & Ohio St      NaN
# 3  587  04/01/2020 12:06:07 AM      Wabash Ave & 83rd St      NaN
# 4   15  04/01/2020 12:06:07 AM      Racine Ave & 18th St      NaN
#
#    Total Docks  Docks in Service  Available Docks  Available Bikes  \
# 0           19                19                9               10
# 1           23                23               10               13
# 2           19                19               13                6
# 3           11                11                4                7
# 4           15                15                6                9
#
#    Percent Full      Status   Latitude  Longitude  \
# 0            53  In Service  41.973340 -87.667780
# 1            57  In Service  41.994780 -87.660285
# ...

# %%
# Station Nameのユニークな値を取得
station_names = df["Station Name"].unique()
print(station_names)
# Out:
# ['Clark St & Winnemac Ave' 'Broadway & Granville Ave'
#  'Lake Shore Dr & Ohio St' 'Wabash Ave & 83rd St' 'Racine Ave & 18th St'
#  'Orleans St & Merchandise Mart Plaza' '63rd St Beach'
#  'Stony Island Ave & 67th St' 'Clinton St & Polk St'
#  'State St & Pearson St' 'Desplaines St & Jackson Blvd'
#  'Halsted St & Polk St' '900 W Harrison St' 'Dearborn St & Erie St'
#  'Sedgwick St & Huron St' 'Jeffery Blvd & 71st St'
#  'Green St & Randolph St' 'Bissell St & Armitage Ave'
#  'Sheffield Ave & Waveland Ave' 'Sheffield Ave & Wellington Ave'
#  'Western Ave & Winnebago Ave' 'Wilton Ave & Belmont Ave'
#  'Sedgwick St & North Ave' 'Ashland Ave & Lake St'
#  'Wentworth Ave & Cermak Rd (Temp)' 'Blackstone Ave & Hyde Park Blvd'
#  'South Shore Dr & 71st St' 'Ogden Ave & Congress Pkwy'
#  'California Ave & Milwaukee Ave' 'Damen Ave & Cullerton St'
#  'Rush St & Hubbard St' 'Clark St & North Ave'
#  'Lincoln Ave & Fullerton Ave' 'Damen Ave & Chicago Ave'
# ...

# %%
print(len(station_names))
# Out:
# 596

# %% [markdown]
# ## ロックダウンと自宅待機勧告の間

# %%
df2 = pd.read_csv("../data/Divvy_Bicycle_Stations_-_Historical (2).csv")
df2.head()
# Out:
#    ID
# 0   2
# 1   3
# 2   4
# 3   5
# 4   6

# %%
print(len(df2["ID"]))
# Out:
# 673
